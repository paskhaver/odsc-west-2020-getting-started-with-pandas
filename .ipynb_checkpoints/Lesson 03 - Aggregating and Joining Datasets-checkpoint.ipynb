# %%
import pandas as pd

# %%
pd.read_csv("sales_by_employee.csv").head()
pd.read_csv("sales_by_employee.csv", parse_dates = ["Date"]).head()
# Out:
#         Date   Name       Customer  Revenue  Expenses
# 0 2020-01-01  Oscar  Logistics XYZ     5250       531
# 1 2020-01-01  Oscar    Money Corp.     4406       661
# 2 2020-01-02  Oscar     PaperMaven     8661      1401
# 3 2020-01-03  Oscar    PaperGenius     7075       906
# 4 2020-01-04  Oscar    Paper Pound     2524      1767

# %%
sales = pd.read_csv("sales_by_employee.csv", parse_dates = ["Date"])

# %%
# All numeric columns will be included in calculation
sales.pivot_table(index = "Date") # is the same as 
sales.pivot_table(index = "Date", aggfunc = "mean")
# Out:
#                Expenses      Revenue
# Date
# 2020-01-01   637.500000  4293.500000
# 2020-01-02  1244.400000  7303.000000
# 2020-01-03  1313.666667  4865.833333
# 2020-01-04  1450.600000  3948.000000
# 2020-01-05  1196.250000  4834.750000

# %%
sales.pivot_table(index = "Date", aggfunc = "count")
# Out:
#             Customer  Expenses  Name  Revenue
# Date
# 2020-01-01         6         6     6        6
# 2020-01-02         5         5     5        5
# 2020-01-03         6         6     6        6
# 2020-01-04         5         5     5        5
# 2020-01-05         4         4     4        4

# %%
sales.pivot_table(index = "Date", aggfunc = "sum")
# Out:
#             Expenses  Revenue
# Date
# 2020-01-01      3825    25761
# 2020-01-02      6222    36515
# 2020-01-03      7882    29195
# 2020-01-04      7253    19740
# 2020-01-05      4785    19339

# %%
# Limit the column(s) whose values are included
sales.pivot_table(index = "Date", aggfunc = "sum", values = "Revenue")
# Out:
#             Revenue
# Date
# 2020-01-01    25761
# 2020-01-02    36515
# 2020-01-03    29195
# 2020-01-04    19740
# 2020-01-05    19339

# %%
# Use unique values on column axis
sales.pivot_table(
    index = "Date",
    columns = "Name",
    values = "Revenue",
    aggfunc = "sum"
)
# Out:
# Name          Creed   Dwight     Jim  Michael   Oscar
# Date
# 2020-01-01   4430.0   2639.0  1864.0   7172.0  9656.0
# 2020-01-02  13214.0      NaN  8278.0   6362.0  8661.0
# 2020-01-03      NaN  11912.0  4226.0   5982.0  7075.0
# 2020-01-04   3144.0      NaN  6155.0   7917.0  2524.0
# 2020-01-05    938.0   7771.0     NaN   7837.0  2793.0

# %%
# Fill in NaN values
sales.pivot_table(
    index = "Date",
    columns = "Name",
    values = "Revenue",
    aggfunc = "sum",
    fill_value = 0
)
# Out:
# Name        Creed  Dwight   Jim  Michael  Oscar
# Date
# 2020-01-01   4430    2639  1864     7172   9656
# 2020-01-02  13214       0  8278     6362   8661
# 2020-01-03      0   11912  4226     5982   7075
# 2020-01-04   3144       0  6155     7917   2524
# 2020-01-05    938    7771     0     7837   2793

# %%
# Fill in NaN values
sales.pivot_table(
    index = "Date",
    columns = "Name",
    values = "Revenue",
    aggfunc = "sum",
    fill_value = 0,
    margins = True
)
# Out:
# Name                 Creed  Dwight    Jim  Michael  Oscar     All
# Date
# 2020-01-01 00:00:00   4430    2639   1864     7172   9656   25761
# 2020-01-02 00:00:00  13214       0   8278     6362   8661   36515
# 2020-01-03 00:00:00      0   11912   4226     5982   7075   29195
# 2020-01-04 00:00:00   3144       0   6155     7917   2524   19740
# 2020-01-05 00:00:00    938    7771      0     7837   2793   19339
# All                  21726   22322  20523    35270  30709  130550

# %% [markdown]
# ## Melting a Dataset

# %%
pd.read_csv("video_game_sales.csv").head()
# Out:
#                        Name     NA     EU     JP  Other
# 0                Wii Sports  41.49  29.02   3.77   8.46
# 1         Super Mario Bros.  29.08   3.58   6.81   0.77
# 2            Mario Kart Wii  15.85  12.88   3.79   3.31
# 3         Wii Sports Resort  15.75  11.01   3.28   2.96
# 4  Pokemon Red/Pokemon Blue  11.27   8.89  10.22   1.00

# %%
video_game_sales = pd.read_csv("video_game_sales.csv")
video_game_sales.head()
# Out:
#                        Name     NA     EU     JP  Other
# 0                Wii Sports  41.49  29.02   3.77   8.46
# 1         Super Mario Bros.  29.08   3.58   6.81   0.77
# 2            Mario Kart Wii  15.85  12.88   3.79   3.31
# 3         Wii Sports Resort  15.75  11.01   3.28   2.96
# 4  Pokemon Red/Pokemon Blue  11.27   8.89  10.22   1.00

# %%
# id is the column with unique identifiers
video_game_sales.melt(id_vars = 'Name', value_vars = "NA").head()
# Out:
#                        Name variable  value
# 0                Wii Sports       NA  41.49
# 1         Super Mario Bros.       NA  29.08
# 2            Mario Kart Wii       NA  15.85
# 3         Wii Sports Resort       NA  15.75
# 4  Pokemon Red/Pokemon Blue       NA  11.27

# %%
# 4 rows for every original row in video_games_sales
video_game_sales.melt(
    id_vars = 'Name',
    value_vars = ["NA", "EU", "JP", "Other"]
)
# Out:
#                                                    Name variable  value
# 0                                            Wii Sports       NA  41.49
# 1                                     Super Mario Bros.       NA  29.08
# 2                                        Mario Kart Wii       NA  15.85
# 3                                     Wii Sports Resort       NA  15.75
# 4                              Pokemon Red/Pokemon Blue       NA  11.27
# ...                                                 ...      ...    ...
# 66259                Woody Woodpecker in Crazy Castle 5    Other   0.00
# 66260                     Men in Black II: Alien Escape    Other   0.00
# 66261  SCORE International Baja 1000: The Official Game    Other   0.00
# 66262                                        Know How 2    Other   0.00
# 66263                                  Spirits & Spells    Other   0.00
#
# [66264 rows x 3 columns]

# %%
# Rename column with variable values and column with values
video_game_sales_by_region = video_game_sales.melt(
    id_vars = 'Name',
    value_vars = ["NA", "EU", "JP", "Other"],
    var_name = "Region",
    value_name = "Sales"
)

video_game_sales_by_region.head()
# Out:
#                        Name Region  Sales
# 0                Wii Sports     NA  41.49
# 1         Super Mario Bros.     NA  29.08
# 2            Mario Kart Wii     NA  15.85
# 3         Wii Sports Resort     NA  15.75
# 4  Pokemon Red/Pokemon Blue     NA  11.27

# %%
video_game_sales_by_region.pivot_table(
    index = "Name",
    values = "Sales",
    aggfunc = "sum"
).head()
# Out:
#                                Sales
# Name
# '98 Koshien                     0.40
# .hack//G.U. Vol.1//Rebirth      0.17
# .hack//G.U. Vol.2//Reminisce    0.23
# .hack//G.U. Vol.3//Redemption   0.17
# .hack//Infection Part 1         1.26

# %% [markdown]
# ## The GroupBy Object

# %%
pd.read_csv("fortune1000.csv").head()
fortune = pd.read_csv("fortune1000.csv")

# %%
sectors = fortune.groupby("Sector")

# %%
fortune.nunique()
# Out:
# Company      1000
# Revenues      951
# Profits       971
# Employees     754
# Sector         21
# Industry       74
# dtype: int64

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense               25
# Apparel                           14
# Business Services                 53
# Chemicals                         33
# Energy                           107
# Engineering & Construction        27
# Financials                       155
# Food &  Drug Stores               12
# Food, Beverages & Tobacco         37
# Health Care                       71
# Hotels, Restaurants & Leisure     26
# Household Products                28
# Industrials                       49
# Materials                         45
# Media                             25
# Motor Vehicles & Parts            19
# Retailing                         77
# Technology                       103
# Telecommunications                10
# Transportation                    40
# Wholesalers                       44
# dtype: int64

# %%
sectors.get_group("Transportation")
# Out:
#                                   Company  Revenues  Profits  Employees  \
# 43                                    UPS   65872.0   4910.0     346415
# 49                                  FedEx   60319.0   2997.0     357000
# 70                American Airlines Group   42207.0   1919.0     126600
# 74                        Delta Air Lines   41244.0   3577.0      86564
# 80            United Continental Holdings   37736.0   2131.0      89800
# 140                         Union Pacific   21240.0  10712.0      41992
# 141                    Southwest Airlines   21171.0   3488.0      56110
# 185                         XPO Logistics   15381.0    340.2      95000
# 192               C.H. Robinson Worldwide   14869.0    504.9      15074
# 264                                   CSX   11408.0   5471.0      24006
# 283                      Norfolk Southern   10551.0   5404.0      27110
# 354                      Alaska Air Group    7933.0   1034.0      23156
# 386                          Ryder System    7330.0    790.6      36100
# 394          J.B. Hunt Transport Services    7190.0    686.3      24681
# 401                       JetBlue Airways    7015.0   1147.0      17424
# 407        Expeditors Intl. of Washington    6921.0    489.3      16500
# 487                       Harley-Davidson    5647.0    521.8       5800
# 495                    Polaris Industries    5505.0    172.5      11000
# 530                             Brunswick    4898.0    146.4      15116
# 531                         YRC Worldwide    4891.0    -10.8      32000
# 566                    Schneider National    4384.0    389.9      19600
# 598                             Hub Group    4035.0    135.2       4377
# 632                    Trinity Industries    3663.0    702.5      15605
# 637                       Landstar System    3649.0    177.1       1273
# 675                                Amerco    3422.0    398.4      20376
# 688             Old Dominion Freight Line    3358.0    463.8      19183
# 706                               SkyWest    3204.0    428.9      16300
# 762                               ArcBest    2827.0     59.7      13000
# 793                     Hawaiian Holdings    2696.0    364.0       6660
# 801                       Spirit Airlines    2648.0    420.6       6100
# 814                  Kansas City Southern    2583.0    962.0       7130
# 848  Knight-Swift Transportation Holdings    2426.0    484.3      25300
# 904                                 Kirby    2214.0    313.2       5775
# 906                     Genesee & Wyoming    2208.0    549.1       8000
# 914                       Greenbrier Cos.    2169.0    116.1      11917
# 918          Atlas Air Worldwide Holdings    2157.0    223.5       2870
# 928                    Werner Enterprises    2117.0    202.9      12154
# 933     Roadrunner Transportation Systems    2082.0   -106.7       4645
# 947                                Matson    2047.0    232.0       1947
# 968                 Echo Global Logistics    1943.0     12.6       2453
#
#              Sector                             Industry
# 43   Transportation  Mail, Package, and Freight Delivery
# 49   Transportation  Mail, Package, and Freight Delivery
# 70   Transportation                             Airlines
# 74   Transportation                             Airlines
# 80   Transportation                             Airlines
# 140  Transportation                            Railroads
# 141  Transportation                             Airlines
# 185  Transportation         Transportation and Logistics
# 192  Transportation         Transportation and Logistics
# 264  Transportation                            Railroads
# 283  Transportation                            Railroads
# 354  Transportation                             Airlines
# 386  Transportation              Trucking, Truck Leasing
# 394  Transportation              Trucking, Truck Leasing
# 401  Transportation                             Airlines
# 407  Transportation         Transportation and Logistics
# 487  Transportation             Transportation Equipment
# 495  Transportation             Transportation Equipment
# 530  Transportation             Transportation Equipment
# 531  Transportation              Trucking, Truck Leasing
# 566  Transportation              Trucking, Truck Leasing
# 598  Transportation         Transportation and Logistics
# 632  Transportation             Transportation Equipment
# 637  Transportation              Trucking, Truck Leasing
# 675  Transportation              Trucking, Truck Leasing
# 688  Transportation              Trucking, Truck Leasing
# 706  Transportation                             Airlines
# 762  Transportation              Trucking, Truck Leasing
# 793  Transportation                             Airlines
# 801  Transportation                             Airlines
# 814  Transportation                            Railroads
# 848  Transportation              Trucking, Truck Leasing
# 904  Transportation                             Shipping
# 906  Transportation                            Railroads
# 914  Transportation             Transportation Equipment
# 918  Transportation         Transportation and Logistics
# 928  Transportation              Trucking, Truck Leasing
# 933  Transportation              Trucking, Truck Leasing
# 947  Transportation                             Shipping
# 968  Transportation         Transportation and Logistics

# %%
sectors.mean()
# Out:
#                                    Revenues      Profits      Employees
# Sector
# Aerospace & Defense            15353.400000  1069.340000   40404.960000
# Apparel                         7225.521429   453.621429   25407.071429
# Business Services               5963.962264   701.494340   30075.452830
# Chemicals                       7610.636364   620.454545   14364.242424
# Energy                         14425.300935   805.373585    9170.158879
# Engineering & Construction      6399.333333   263.740741   15583.148148
# Financials                     15757.935484  1704.861290   22581.412903
# Food &  Drug Stores            33789.000000   703.358333  116506.166667
# Food, Beverages & Tobacco      13790.054054  1483.851351   29170.702703
# Health Care                    21239.315493  1306.916901   41847.732394
# Hotels, Restaurants & Leisure   6916.346154   819.442308   88628.346154
# Household Products              8277.850000   990.242857   24103.428571
# Industrials                    10615.102041   390.087755   31961.428571
# Materials                       6184.400000   305.120000   14527.800000
# Media                           9219.496000   920.796000   21839.400000
# Motor Vehicles & Parts         22817.631579   361.110526   49662.210526
# Retailing                      21874.714286   723.470130   88320.233766
# Technology                     13347.789320  1743.959804   31036.961165
# Telecommunications             46695.900000  9196.580000   78560.900000
# Transportation                 11379.000000  1324.007500   41302.825000
# Wholesalers                    20185.204545   355.850000   16913.068182

# %%
sectors["Profits"].mean()
sectors["Profits"].sum()
sectors["Profits"].median()
sectors["Profits"].max()
sectors["Profits"].min()
# Out:
# Sector
# Aerospace & Defense               -74.0
# Apparel                          -478.2
# Business Services                -557.1
# Chemicals                        -296.2
# Energy                          -5723.0
# Engineering & Construction       -332.2
# Financials                      -6798.0
# Food &  Drug Stores              -373.3
# Food, Beverages & Tobacco        -286.2
# Health Care                     -2459.0
# Hotels, Restaurants & Leisure    -375.0
# Household Products              -1053.8
# Industrials                     -5786.0
# Materials                        -258.0
# Media                            -738.0
# Motor Vehicles & Parts          -3864.0
# Retailing                       -1067.3
# Technology                      -3728.0
# Telecommunications              -2116.6
# Transportation                   -106.7
# Wholesalers                      -267.0
# Name: Profits, dtype: float64
